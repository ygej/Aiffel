# %% [markdown]
# # 깜퀴_20200929_01

# %% [markdown]
# # 문제 1
# 메이플스토리 능력치 뽑기 주사위 만들기
#
# ![메이플 스토리 능력치 주사위](https://images.app.goo.gl/sZyoAhaj75UspgCCA)

# %%
from random import randrange

class MapleDice:
    def __init__(self, job = None):
        self.stat_list = [i for i in range(0,4)]
        self.options = randrange(4,13)
        self.job = job
        
    def throw(self):
        stat_list = []
        for i in [i for i in range(0,4)]:
            if i == 0:
                i = randrange(4,13)
            elif i == 1 and stat_list[0] > 4 :
                i = randrange(4,18-(stat_list[0]))
            elif i == 2 and sum(stat_list) > 8:
                i = randrange(4, 22 - sum(stat_list))
            elif i == 2 and sum(stat_list) < 9:
                i = randrange(5, 13)
            elif i == 3:
                i = 25 - sum(stat_list)
            else:
                i = randrange(4,13)
            stat_list.append(i)
        print("나의 캐릭터 스탯 \nSTR:{0}, INT:{1}, DEX:{2}, LUK:{3}".format(stat_list[0],stat_list[1],stat_list[2],stat_list[3]))
    
    def auto_mouse(self, job = None):
        self.job = job
        if self.job > 4 or self.job < 0:
            print("숫자를 다시 입력하세요. \n 전사 = 0, 법사 = 1, 궁수 = 2, 도적 = 3")
            
        # 전사 & 궁수
        if self.job == 0 or self.job == 2:
            count = 0
            while True:
                stat_list = []
                for i in [i for i in range(0,4)]:
                    if i == 0:
                        i = randrange(4,13)
                    elif i == 1 and stat_list[0] > 4 :
                        i = randrange(4,18-(stat_list[0]))
                    elif i == 2 and sum(stat_list) > 8:
                        i = randrange(4, 22 - sum(stat_list))
                    elif i == 2 and sum(stat_list) < 9:
                        i = randrange(5, 13)
                    elif i == 3:
                        i = 25 - sum(stat_list)
                    else:
                        i = randrange(4,13)
                    stat_list.append(i)
                
                if stat_list[1] == 4 and stat_list[3] == 4:
                    break
                count += 1
                
        # 법사
        if self.job == 1:
            count = 0
            while True:
                stat_list = []
                for i in [i for i in range(0,4)]:
                    if i == 0:
                        i = randrange(4,13)
                    elif i == 1 and stat_list[0] > 4 :
                        i = randrange(4,18-(stat_list[0]))
                    elif i == 2 and sum(stat_list) > 8:
                        i = randrange(4, 22 - sum(stat_list))
                    elif i == 2 and sum(stat_list) < 9:
                        i = randrange(5, 13)
                    elif i == 3:
                        i = 25 - sum(stat_list)
                    else:
                        i = randrange(4,13)
                    stat_list.append(i)
                
                if stat_list[0] == 4 and stat_list[2] == 4:
                    break
                count += 1
                
        # 도적
        if self.job == 3:
            count = 0
            while True:
                stat_list = []
                for i in [i for i in range(0,4)]:
                    if i == 0:
                        i = randrange(4,13)
                    elif i == 1 and stat_list[0] > 4 :
                        i = randrange(4,18-(stat_list[0]))
                    elif i == 2 and sum(stat_list) > 8:
                        i = randrange(4, 22 - sum(stat_list))
                    elif i == 2 and sum(stat_list) < 9:
                        i = randrange(5, 13)
                    elif i == 3:
                        i = 25 - sum(stat_list)
                    else:
                        i = randrange(4,13)
                    stat_list.append(i)
                
                if stat_list[0] == 4 and stat_list[1] == 4:
                    break
                count += 1
                   
                
        print("오토마우스 결과\n나의 캐릭터 스탯\nSTR:{0}, INT:{1}, DEX:{2}, LUK:{3}\n{4}번 만에 성공했습니다!".format(stat_list[0],stat_list[1],stat_list[2],stat_list[3],count))

# %%
my_stat = MapleDice()
my_stat.throw()
# Out:
# 나의 캐릭터 스탯
# STR:8, INT:8, DEX:4, LUK:5

# %%
for i in range(500):
    my_stat.auto_mouse(3)
# Out:
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 9번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 27번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 45번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 112번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 205번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 51번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 43번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 107번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 167번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 125번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 44번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 15번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 116번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 71번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 18번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 91번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 148번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 186번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 210번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 82번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 25번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 21번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 27번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 4번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 55번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 5번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 90번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 165번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 138번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 56번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 110번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 232번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 269번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 5번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 23번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 77번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 128번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 182번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 56번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 8번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 69번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 115번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 144번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 89번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 11번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 12번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 12번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 267번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 8번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 19번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 327번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 70번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 108번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 16번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 87번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 252번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 17번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 65번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 41번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 38번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 69번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 42번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 98번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 177번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 44번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 190번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 123번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 10번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 13번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 13번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 11번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 93번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 106번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 1번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 90번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 14번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 69번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 11번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 3번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 68번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 20번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 126번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 111번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 36번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 165번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 23번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 1번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 641번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 41번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 4번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 13번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 30번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 13번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 76번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 9번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 28번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 18번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 67번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 103번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 13번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 140번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 52번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 153번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 52번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 38번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 122번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 63번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 95번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 53번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 38번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 124번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 3번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 141번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 63번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 4번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 23번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 446번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 18번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 156번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 33번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 74번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 70번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 45번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 36번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 83번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 20번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 29번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 207번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 2번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 30번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 126번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 389번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 1번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 1번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 101번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 151번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 100번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 56번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 1번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 68번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 329번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 62번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 49번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 44번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 42번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 24번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 165번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 113번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 30번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 25번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 49번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 46번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 4번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 233번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 9번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 55번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 150번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 160번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 14번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 74번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 5번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 117번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 40번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 4번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 115번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 161번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 215번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 225번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 155번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 50번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 6번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 12번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 97번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 98번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 39번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 20번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 114번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 57번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 49번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 69번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 36번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 10번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 45번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 201번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 9번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 18번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 50번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 151번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 53번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 183번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 66번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 84번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 257번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 68번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 99번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 19번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 193번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 48번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 68번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 18번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 24번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 21번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 125번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 100번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 206번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 47번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 84번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 4번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 20번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 76번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 119번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 20번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 8번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 45번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 107번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 63번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 20번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 16번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 34번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 47번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 26번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 51번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 207번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 17번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 5번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 23번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 391번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 320번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 6번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 148번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 21번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 24번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 26번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 264번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 132번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 97번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 38번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 75번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 20번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 55번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 138번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 46번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 3번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 32번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 3번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 7번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 248번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 111번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 366번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 129번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 44번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 98번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 66번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 24번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 66번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 44번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 59번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 86번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 21번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 168번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 65번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 83번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 30번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 35번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 206번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 62번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 30번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 46번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 109번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 39번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 90번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 100번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 78번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 69번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 16번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 141번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 279번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 94번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 84번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 79번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 4번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 54번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 7번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 17번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 191번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 20번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 116번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 76번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 114번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 369번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 198번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 95번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 89번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 12번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 5번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 59번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 161번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 201번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 11번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 29번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 390번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 52번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 112번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 284번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 63번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 24번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 61번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 6번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 17번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 54번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 168번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 15번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 26번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 8번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 45번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 185번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 24번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 100번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 9번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 101번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 162번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 23번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 78번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 266번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 277번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 61번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 118번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 185번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 93번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 64번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 59번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 237번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 44번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 46번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 64번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 62번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 127번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 37번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 6번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 48번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 111번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 232번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 164번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 430번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 35번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 177번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 112번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 109번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 148번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 70번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 57번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 94번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 16번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 176번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 40번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 107번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 126번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 52번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 113번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 59번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 25번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 58번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 216번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 240번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 4번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 553번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 22번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 144번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 6번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 53번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 27번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 17번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 39번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 84번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 57번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 27번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 191번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 22번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 90번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 70번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 170번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 17번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 170번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 309번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 15번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 57번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 11번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 61번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 95번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 134번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 14번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 4번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 22번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 386번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 46번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 120번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 33번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 41번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 16번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 152번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 36번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 179번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 283번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 80번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 18번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 36번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 36번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 371번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 15번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 86번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 47번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 204번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 90번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 38번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 174번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 14번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 10번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 95번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 3번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 218번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 113번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 111번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 58번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 25번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 156번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 45번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 80번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 72번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 8번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 199번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 8번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 6번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 43번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 1번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 281번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 61번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 18번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 217번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 76번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 29번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 37번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 49번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 307번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 61번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 28번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 19번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 56번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 5번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 164번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 7번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 88번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 48번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 138번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 81번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 111번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 92번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 46번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 100번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 9번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 83번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 16번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 10번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 123번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 104번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 111번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 14번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 13번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 80번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 37번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 29번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 147번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 42번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 128번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 2번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 19번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 153번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 228번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 211번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 70번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 112번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:10, LUK:7
# 3번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:8, LUK:9
# 0번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 59번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:6, LUK:11
# 46번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:5, LUK:12
# 160번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 83번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:12, LUK:5
# 30번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:9, LUK:8
# 13번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 43번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:7, LUK:10
# 36번 만에 성공했습니다!
# 오토마우스 결과
# 나의 캐릭터 스탯
# STR:4, INT:4, DEX:11, LUK:6
# 3번 만에 성공했습니다!
